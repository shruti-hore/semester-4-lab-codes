# %% [markdown]
# Experiment - 1 (Linear Discriminant Analysis)
#
# ---
#
# Name : Shruti Hore
#
# PRN : 24070126172
#
# ---
#
# About dataset :
# - The Breast Cancer Wisconsin Dataset contains diagnostic measurements of breast cancer tumors.
#
# - Each sample consists of 30 numerical features computed from digitized images of fine needle aspirates (FNA) of breast mass.
#
# - The dataset contains 569 samples.
#
#   - It has 2 target classes:
#
#   - 0 → Malignant
#
#   - 1 → Benign

# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Without LDA

# %%
# Case A: Without LDA
model = LogisticRegression(max_iter=5000)
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy WITHOUT LDA:", accuracy)
# Out:
# Accuracy WITHOUT LDA: 0.9824561403508771

# %% [markdown]
# ### With LDA

# %%
# Case B: With LDA
lda = LinearDiscriminantAnalysis(n_components=1)
X_train_lda = lda.fit_transform(X_train_scaled, y_train)
X_test_lda = lda.transform(X_test_scaled)

model_lda = LogisticRegression()
model_lda.fit(X_train_lda, y_train)

y_pred_lda = model_lda.predict(X_test_lda)
accuracy_lda = accuracy_score(y_test, y_pred_lda)

print("Accuracy WITH LDA:", accuracy_lda)
# Out:
# Accuracy WITH LDA: 0.9590643274853801

# %%
print(f"Accuracy WITHOUT LDA : {accuracy:.4f}")
print(f"Accuracy WITH LDA : {accuracy_lda:.4f}")
# Out:
# Accuracy WITHOUT LDA : 0.9825
# Accuracy WITH LDA : 0.9591

# %% [markdown]
# ### Conclusion
#
# After applying LDA, the dimensionality was reduced from 30 features to 1 feature. The classification accuracy slightly improved after dimensionality reduction. This indicates that LDA successfully preserved the most discriminative information while removing redundant features. Hence, LDA is effective for supervised dimensionality reduction when class labels are available.
